# %%
from ultralytics import YOLO

# %%
model = YOLO('../../weights/yolov8x-pose.pt')

# %%
results = model.train(data="dataset.yaml", epochs=5, batch=128 , freeze=10)
# Out:
# New https://pypi.org/project/ultralytics/8.2.101 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.100 🚀 Python-3.11.9 torch-2.4.0 CUDA:0 (NVIDIA L40S, 45596MiB)
# ...
