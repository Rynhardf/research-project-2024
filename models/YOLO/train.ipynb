# %%
from ultralytics import YOLO

# %%
model = YOLO('../../weights/yolov8x-pose-p6.pt')

# %%
results = model.train(data="dataset.yaml", epochs=5, batch=32, freeze=12)
# Out:
# Ultralytics YOLOv8.2.100 🚀 Python-3.11.9 torch-2.4.0 CUDA:0 (NVIDIA L40S, 45596MiB)
# ...
