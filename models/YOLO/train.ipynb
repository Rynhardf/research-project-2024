# %%
from ultralytics import YOLO

# %%
model = YOLO('../../weights/yolov8n-pose.pt')

# %%
results = model.train(data="./dataset_34.yaml", epochs=5, batch=512 , freeze=10, device=1)
# Out:
# New https://pypi.org/project/ultralytics/8.3.2 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.79 🚀 Python-3.11.9 torch-2.4.0 CUDA:1 (NVIDIA L40S, 45596MiB)
# ...
